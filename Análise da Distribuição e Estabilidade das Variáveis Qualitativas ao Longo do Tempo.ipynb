# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %% [markdown]
# **Resposta:**
# * Somente a distribuição de educação ao longo do tempo que a partir de 08/2015 teve um aumento significativo no ensino superior completo, se mantendo o aumento durante os próximos meses.

# %%
# Carregando arquivo CSV em um dataframe
df = pd.read_csv('previsao_de_renda.csv')

# Convertendo a coluna "data_ref" para o tipo datetime
df['data_ref'] = pd.to_datetime(df['data_ref'])

# Selecionando as variáveis qualitativas
qualitative_vars = ["sexo", "posse_de_veiculo", "posse_de_imovel", "tipo_renda", "educacao", "estado_civil", "tipo_residencia"]

# Plotando os gráficos de barras para cada variável qualitativa ao longo do tempo
for var in qualitative_vars:
    plt.figure(figsize=(12, 6))
    plt.title(f"Distribuição de {var} ao longo do tempo")
    sns.countplot(x='data_ref', hue=var, data=df)
    plt.xticks(rotation=45)
    plt.xlabel("Data de Referência")
    plt.ylabel("Contagem")
    plt.legend(loc='upper right')
    plt.show()

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %% [markdown]
# **Resposta:**
#
# * O gráfico da variável Educação ao Longo do Tempo se mostrou instável após a construção do gráfico mostrando as médias. É possível sim utilizar a maioria das variáveis deste dataframa em uma modelagem.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carregando arquivo CSV em um dataframe
df = pd.read_csv('previsao_de_renda.csv')

# Convertendo a coluna "data_ref" para o tipo datetime
df['data_ref'] = pd.to_datetime(df['data_ref'])

# Selecionando as variáveis qualitativas
qualitative_vars = ["sexo", "posse_de_veiculo", "posse_de_imovel", "tipo_renda", "educacao", "estado_civil", "tipo_residencia"]

# Ajustando o tamanho dos gráficos e a rotação dos rótulos do eixo x
plt.figure(figsize=(30, 30))

# Plotando os gráficos de barras para cada variável qualitativa com as médias ao longo do tempo
for i, var in enumerate(qualitative_vars, 1):
    plt.subplot(3, 3, i)
    sns.barplot(x='data_ref', y='renda', hue=var, data=df)
    plt.title(f"Médias de Renda por {var}")
    plt.xlabel("Data de Referência")
    plt.ylabel("Média de Renda")
    plt.xticks(rotation=45)
    plt.legend(loc='upper right')

plt.tight_layout()
plt.show()
